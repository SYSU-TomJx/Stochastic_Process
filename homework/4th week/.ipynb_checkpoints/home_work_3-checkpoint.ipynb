# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
MARKS = ['o','v','x','+','D']
n = 10
n_i = [i for i in range(0,n+1)]

# %% [markdown]
# ### 参考教材figure2.1, 编写程序仿真。分别画5个n=10的样本函数，体会到达过程和泊松过程。

# %% [markdown]
# #### 1. 更新过程，间隔时间通过掷一枚均匀骰子决定，投到多少点，间隔就取多少。

# %%
for i in range(5):
    x_i = np.random.randint(low=1,high=7, size=(n))
    s_i = [np.sum(x_i[0:i]) for i in range(1,n+1)]
    print('x_'+str(i+1)+'=', x_i,',s_'+str(i+1)+'=', s_i)
    plt.step(s_i, n_i[1:],label=str(i+1), marker=MARKS[i])
plt.legend()
plt.xlabel('$S_n$')
plt.title('Renewal Processes')
plt.show()
# Out:
# x_1= [4 1 4 2 5 6 5 5 5 5] ,s_1= [4, 5, 9, 11, 16, 22, 27, 32, 37, 42]
# x_2= [5 3 1 4 6 5 1 6 6 2] ,s_2= [5, 8, 9, 13, 19, 24, 25, 31, 37, 39]
# x_3= [5 3 3 6 3 5 4 6 4 6] ,s_3= [5, 8, 11, 17, 20, 25, 29, 35, 39, 45]
# x_4= [1 4 4 3 2 4 2 5 2 3] ,s_4= [1, 5, 9, 12, 14, 18, 20, 25, 27, 30]
# x_5= [2 1 1 6 6 6 4 2 1 2] ,s_5= [2, 3, 4, 10, 16, 22, 26, 28, 29, 31]

# %% [markdown]
# #### 2. 更新过程，间隔时间服从[0,1]上的均匀分布。

# %%
x_un = []
s_un = []
for i in range(5):
    x_i_un = np.random.uniform(low=0.0, high=1.0, size=(n))
    x_i_un = np.around(x_i_un,decimals=3)
    s_i_un = [np.sum(x_i_un[0:i]) for i in range(1,n+1)]
    s_i_un = np.around(s_i_un, decimals=3)
    print('x_'+str(i+1)+'=', x_i_un,',s_'+str(i+1)+'=', s_i_un)
    plt.step(s_i_un, n_i[1:], label=str(i+1), marker=MARKS[i])
plt.legend()
plt.title('Renewal Processes')
plt.xlabel('$S_n$')
plt.show()
# Out:
# x_1= [0.386 0.769 0.353 0.578 0.025 0.142 0.81  0.515 0.486 0.65 ] ,s_1= [0.386 1.155 1.508 2.086 2.111 2.253 3.063 3.578 4.064 4.714]
# x_2= [0.9   0.522 0.445 0.784 0.11  0.677 0.336 0.856 0.109 0.785] ,s_2= [0.9   1.422 1.867 2.651 2.761 3.438 3.774 4.63  4.739 5.524]
# x_3= [0.089 0.59  0.367 0.889 0.3   0.87  0.619 0.327 0.007 0.418] ,s_3= [0.089 0.679 1.046 1.935 2.235 3.105 3.724 4.051 4.058 4.476]
# x_4= [0.686 0.58  0.723 0.207 0.598 0.335 0.846 0.788 0.993 0.796] ,s_4= [0.686 1.266 1.989 2.196 2.794 3.129 3.975 4.763 5.756 6.552]
# x_5= [0.38  0.983 0.256 0.153 0.883 0.231 0.364 0.156 0.78  0.901] ,s_5= [0.38  1.363 1.619 1.772 2.655 2.886 3.25  3.406 4.186 5.087]

# %% [markdown]
# #### 3. 泊松过程$\lambda$=1。

# %%
n = 10
for i in range(5):
    x_i_po = np.random.poisson(lam=1.0, size=(n))
    s_i_po = [np.sum(x_i_po[0:i]) for i in range(1,n+1)]
    print('x_'+str(i+1)+'=', x_i_po,',s_'+str(i+1)+'=', s_i_po)
    plt.step(s_i_po, n_i[1:], label=str(i+1), marker=MARKS[i])
plt.legend()
plt.xlabel('$S_n$')
plt.title('Poission Processes')
plt.show()
# Out:
# x_1= [4 2 0 0 1 0 0 1 3 0] ,s_1= [4, 6, 6, 6, 7, 7, 7, 8, 11, 11]
# x_2= [1 0 3 1 1 0 0 0 1 3] ,s_2= [1, 1, 4, 5, 6, 6, 6, 6, 7, 10]
# x_3= [2 1 2 0 0 0 1 0 1 3] ,s_3= [2, 3, 5, 5, 5, 5, 6, 6, 7, 10]
# x_4= [1 0 0 1 2 2 0 1 1 1] ,s_4= [1, 1, 1, 2, 4, 6, 6, 7, 8, 9]
# x_5= [1 0 4 1 3 5 0 1 0 1] ,s_5= [1, 1, 5, 6, 9, 14, 14, 15, 15, 16]
